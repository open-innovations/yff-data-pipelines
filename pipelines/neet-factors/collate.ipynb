# %%
import os
import pandas as pd
import zipfile

# %%
def read_csvs_from_zip(zip_path: str, csv_path: str, *args, **kwargs) -> pd.DataFrame:
    with zipfile.ZipFile(zip_path) as zip:
        with zip.open(csv_path) as csv:
            data = pd.read_csv(csv, *args, **kwargs)
    return data

# %% [markdown]
# Load `children_in_poverty` data

# %%
children_in_poverty = pd.read_excel(
    '../../data/raw/neet-factors/children-in-low-income-families-local-area-statistics-2014-to-2022.ods',
    sheet_name='4_Absolute_Local_Authority',
    skiprows=9,
    usecols=[1, 17],
    names=['geography_code', 'Children in poverty'],
    index_col=0
).iloc[:, 0].mul(100).round(1)

# %% [markdown]
# Load `children_looked_after` data

# %%
children_looked_after = read_csvs_from_zip(
          '../../data/raw/neet-factors/cla-all.zip',
          'data/cla_number_and_rate_per_10k_children.csv',
          usecols=[
            'time_period',
            'geographic_level',
            'population_count',
            'new_la_code',
            'rate_per_10000'
          ],
          index_col='new_la_code'
        )

children_looked_after = children_looked_after.loc[
  (children_looked_after.geographic_level == 'Local authority') &
  (children_looked_after.population_count == 'Children looked after at 31 March each year') &
  (children_looked_after.time_period == 2022),
  ["rate_per_10000"]
].rename(columns={
  'rate_per_10000': 'Children looked after'
})

# %% [markdown]
# Load `health_disability` data

# %%
health_disability_2021 = pd.read_csv('../../data/raw/neet-factors/health_disability_2021.csv', index_col='Lower tier local authorities Code')

sum = health_disability_2021.loc[
  (health_disability_2021['Disability (3 categories)'] == 'Disabled under the Equality Act') &
  (health_disability_2021['Age (C) (4 categories)'].isin(['Aged 15 years and under', 'Aged 16 to 24 years' ])),
  "Observation"
].groupby('Lower tier local authorities Code').sum()

total = health_disability_2021.loc[
  (health_disability_2021['Age (C) (4 categories)'].isin(['Aged 15 years and under', 'Aged 16 to 24 years' ])),
  "Observation"
].groupby('Lower tier local authorities Code').sum()

health_disability_2021 = (sum/total).mul(100).to_frame('Disability (age < 25)')

# %% [markdown]
# Load `family_disability_2021` data

# %%
family_disability_2021 = pd.read_csv(
  filepath_or_buffer='../../data/raw/neet-factors/family_disability_2021.csv',
  index_col='Lower tier local authorities Code'
)

sum = family_disability_2021.loc[
  family_disability_2021['Disability - Equality act disabled (4 categories) Code'].isin([1]),
  "Observation"
].groupby('Lower tier local authorities Code').sum()

total = family_disability_2021.loc[
  :,
  "Observation"
].groupby('Lower tier local authorities Code').sum()

family_disability_2021 = (sum/total).mul(100).to_frame('Disability (all)')

# %% [markdown]
# Load `economic_inactivity` data.
#
# This is not the same value as in the spreadsheet. Need to double check logic.

# %%
economic_inactivity = pd.read_csv(
  '../../data/raw/neet-factors/economic_inactivity_status.csv',
  index_col='Lower tier local authorities Code'
)

in_age_range = economic_inactivity['Age (C) (4 categories)'] == 'Aged 16 to 24 years'
is_economically_inactive = economic_inactivity['Economic activity status (7 categories)'] == 'Economically inactive (excluding full-time students)'

val = economic_inactivity.loc[in_age_range & is_economically_inactive, 'Observation'].groupby('Lower tier local authorities Code').sum()
total = economic_inactivity.loc[in_age_range, 'Observation'].groupby('Lower tier local authorities Code').sum()

economic_inactivity = ( val / total ).mul(100).to_frame('Economic inactivity (NEET)')

# %% [markdown]
# Load `fertility` data

# %%
fertility = pd.read_csv(
    '../../data/raw/neet-factors/fertility_rates.csv', index_col=[
        'GEOGRAPHY_CODE',
        'MEASURE_NAME',
    ], usecols=[
        'GEOGRAPHY_CODE',
        'MEASURE_NAME',
        'OBS_VALUE',
        # 'OBS_STATUS',
        # 'OBS_STATUS_NAME',
        # 'OBS_CONF',
        # 'OBS_CONF_NAME',
    ]
)

fertility = fertility.squeeze().unstack().rename(columns={
    'Age specific fertility rate : Aged under 20': 'Fertility rates (age < 20)',
    'Age specific fertility rate : Aged 20-24': 'Fertility rates (age 20-24)'
})

# %% [markdown]
# Create `imd` data - crime and health

# %%
imd_health = pd.read_excel(
  '../../data/raw/neet-factors/File_10_-_IoD2019_Local_Authority_District_Summaries__lower-tier__.xlsx',
  sheet_name='Health',
  usecols='A,E',
  names=['geography_code', 'IMD Health'],
  index_col='geography_code',
)
imd_crime = pd.read_excel(
  '../../data/raw/neet-factors/File_10_-_IoD2019_Local_Authority_District_Summaries__lower-tier__.xlsx',
  sheet_name='Crime',
  usecols='A,E',
  names=['geography_code', 'IMD Crime'],
  index_col='geography_code',
)

# %% [markdown]
# Load `lone_parent_household` data

# %%
lone_parent_households = pd.read_excel(
    '../../data/raw/neet-factors/aps2004to2019finalv2.xlsx',
    sheet_name='Lone_parent_households',
    usecols="A,T",
    skiprows=10,
    names=['geography_code', 'lone_parent_households'],
    index_col='geography_code',
    na_values=['[u]', '[w]'],
).join(pd.read_excel(
    '../../data/raw/neet-factors/aps2004to2019finalv2.xlsx',
    sheet_name='Total_households',
    usecols="A,T",
    skiprows=10,
    names=['geography_code', 'total_households'],
    index_col='geography_code',
    na_values=['[u]', '[w]'],
))

lone_parent_households = (lone_parent_households.lone_parent_households / lone_parent_households.total_households).mul(100).to_frame('Lone parent households')

# %% [markdown]
# Add `pupils_with_sen_support` data

# %%
def sen_filter(data):
    return data.loc[
        (data.time_period == 202223)
        & (data.geographic_level == 'Local authority')
        & (data.hospital_school == 'Total')
        & (data.type_of_establishment == 'Total')
        & (data.phase_type_grouping == 'Total')
        ,
        [
          'sen_support_percent'
        ]
    ]
pupils_with_sen_support = read_csvs_from_zip(
  '../../data/raw/neet-factors/special-educational-needs-in-england_2022-23.zip',
  csv_path='data/sen_phase_type_.csv',
  index_col=[
      'new_la_code',
  ],
  na_values=['z']
).pipe(sen_filter).rename(columns={'sen_support_percent': 'Pupils with SEN support'}).sort_index()

# %% [markdown]
# Load `qualifications` data

# %%
def filter_qualifications_16_24(d: pd.DataFrame) -> pd.DataFrame:
    return d.loc[
      (d['Age (C) (4 categories)'] == 'Aged 16 to 24 years'),
      [
        'Highest level of qualification (7 categories) Code',
        'Observation'
      ]
    ]

def filter_qualifications_25_plus(d: pd.DataFrame) -> pd.DataFrame:
    return d.loc[
      (d['Age (C) (4 categories)'].isin(['Aged 25 to 49 years', 'Aged 50 years and over'])),
      [
        'Highest level of qualification (7 categories) Code',
        'Observation'
      ]
    ]

def calc_pct_below_level_2(d):
    return (
      d.loc[
        d['Highest level of qualification (7 categories) Code'].between(0, 1, inclusive='both')
      ].groupby('Lower tier local authorities Code').Observation.sum()
      /
      d.groupby('Lower tier local authorities Code').Observation.sum()
    ).mul(100)

qualifications_16_24 = pd.read_csv(
  '../../data/raw/neet-factors/qualifications_below_level_2.csv',
  index_col=[
    'Lower tier local authorities Code',
  ]
).pipe(filter_qualifications_16_24).pipe(calc_pct_below_level_2).to_frame('Qualification below level 2 (age 16-24)')

qualifications_all = pd.read_csv(
  '../../data/raw/neet-factors/qualifications_below_level_2.csv',
  index_col=[
    'Lower tier local authorities Code',
  ]
).pipe(filter_qualifications_25_plus).pipe(calc_pct_below_level_2).to_frame('Qualification below level 2 (all)')

# %% [markdown]
# Add school absences data

# %%
school_absences = read_csvs_from_zip(
  '../../data/raw/neet-factors/school_absence_by_geographic_area.zip',
  csv_path='data/1_absence_3term_nat_reg_la.csv',
  index_col='new_la_code',
).query('time_period == 202122 & geographic_level == "Local authority" & school_type == "Total"')

school_absences = (school_absences.sess_overall / school_absences.sess_possible).mul(100).sort_index().to_frame('School Absences')

# %% [markdown]
# Add school suspension or exclusion data

# %%
school_data = (
    read_csvs_from_zip(
        '../../data/raw/neet-factors/permanent-and-fixed-period-exclusions-in-england_2022-23-autumn-term.zip',
        csv_path='data/exc_school_20230808.csv',
        index_col='new_la_code',
        usecols=[
          'new_la_code',
          'time_period',
          'headcount',
          'perm_excl',
          'suspension',
        ]
    )
    .query(
        'time_period == 202122'
    )
    .loc[
        :, ['headcount', 'perm_excl', 'suspension']
    ]
    .groupby('new_la_code')
    .sum()
    .sort_index()
)

school_data = pd.concat(
  [
    (school_data.perm_excl / school_data.headcount).mul(100),
    (school_data.suspension / school_data.headcount).mul(100)
  ],
  axis=1
).rename(columns={
    0: 'School Exclusions',
    1: 'School Suspensions'
  },
)

# %% [markdown]
# Add social renting data

# %%
def calc_pct_social_rented(d):
    numerator = d.loc[d['Tenure of household (9 categories)'].str.startswith('Social rented')].groupby('Lower tier local authorities Code').Observation.sum()
    denominator = d.groupby('Lower tier local authorities Code').Observation.sum()
    return (numerator / denominator).mul(100).to_frame('Socially renting households')

social_renting = pd.read_csv(
  '../../data/raw/neet-factors/socially_renting_households.csv',
  index_col='Lower tier local authorities Code',
).pipe(calc_pct_social_rented)

# %% [markdown]
# Add caring responsibility data

# %%
def filter_young_people(d):
    return d.loc[d['Age (6 categories)'] == 'Aged 16 to 24 years']

def calc_pct(d: pd.DataFrame):
    numerator = d.loc[d['Unpaid care (5 categories) Code'].ge(2)].groupby('Lower tier local authorities Code').Observation.sum()
    denominator = d.groupby('Lower tier local authorities Code').Observation.sum()
    return (numerator / denominator).mul(100).to_frame('Unpaid carer (age 16-24)')

unpaid_carer = pd.read_csv(
  '../../data/raw/neet-factors/unpaid_carer.csv',
  index_col='Lower tier local authorities Code',
).pipe(filter_young_people).pipe(calc_pct)

# %% [markdown]
# Create base data frame

# %%
local_authorities = pd.read_csv('../../data/reference/local_authorities.csv', index_col=[0])

# %% [markdown]
# Collate all layers into a single file

# %%
data = (
  local_authorities
    .join(children_in_poverty)
    .join(children_looked_after)
    .join(health_disability_2021)
    .join(family_disability_2021)
    .join(economic_inactivity)
    .join(fertility)
    .join(imd_health)
    .join(imd_crime)
    .join(lone_parent_households)
    .join(pupils_with_sen_support)
    .join(qualifications_16_24)
    .join(qualifications_all)
    .join(school_absences)
    .join(school_data)
    .join(social_renting)
    .join(unpaid_carer)
    .set_index(['Local Authority Name', 'Group'], append=True)
  )

# %% [markdown]
# Save to a CSV file

# %%
SOURCES_CSV='../../data/processed/yff/neet-factors-sources.csv'
os.makedirs(os.path.dirname(SOURCES_CSV), exist_ok=True)
data.melt(ignore_index=False).to_csv(SOURCES_CSV)

# %% [markdown]
# Data that seems wrong:
#
# * Economic inactivity (NEET) - big difference
# * Fertility rates (20-24) - small difference
# * Qualification below level 2 (all)

# %%
data
# Out:
#                                                                                      Children in poverty  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                 21.7
# E06000002            Middlesbrough        Manufacturing Traits                                      31.8
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                 22.0
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                 19.0
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                 20.5
# ...                                                                                                  ...
# E09000029            Sutton               Suburban Traits                                            8.3
# E09000030            Tower Hamlets        London Cosmopolitan                                       21.8
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                   16.8
# E09000032            Wandsworth           London Cosmopolitan                                        9.4
# E09000033            Westminster          NaN                                                       11.6
#
#                                                                                     Children looked after  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                   155
# E06000002            Middlesbrough        Manufacturing Traits                                        150
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                   125
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                   133
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                   123
# ...                                                                                                   ...
# E09000029            Sutton               Suburban Traits                                              48
# E09000030            Tower Hamlets        London Cosmopolitan                                          52
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                      53
# E09000032            Wandsworth           London Cosmopolitan                                          41
# E09000033            Westminster          NaN                                                          56
#
#                                                                                      Disability (age < 25)  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy              10.124733
# E06000002            Middlesbrough        Manufacturing Traits                                    8.978449
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy              10.040150
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy               9.688022
# E06000005            Darlington           Services, Manufacturing and Mining Legacy               9.393366
# ...                                                                                                    ...
# E09000029            Sutton               Suburban Traits                                         7.783485
# E09000030            Tower Hamlets        London Cosmopolitan                                     6.975956
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                 5.819617
# E09000032            Wandsworth           London Cosmopolitan                                     6.468367
# E09000033            Westminster          NaN                                                     6.480722
#
#                                                                                      Disability (all)  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy         11.311311
# E06000002            Middlesbrough        Manufacturing Traits                              10.800000
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy         10.100000
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy          9.109109
# E06000005            Darlington           Services, Manufacturing and Mining Legacy          8.391608
# ...                                                                                               ...
# E09000029            Sutton               Suburban Traits                                    6.400000
# E09000030            Tower Hamlets        London Cosmopolitan                               10.400000
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living            7.700000
# E09000032            Wandsworth           London Cosmopolitan                                6.506507
# E09000033            Westminster          NaN                                                7.807808
#
#                                                                                      Economic inactivity (NEET)  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                   12.079055
# E06000002            Middlesbrough        Manufacturing Traits                                        11.562345
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                   11.305419
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                   10.400090
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                    9.726138
# ...                                                                                                         ...
# E09000029            Sutton               Suburban Traits                                              7.041275
# E09000030            Tower Hamlets        London Cosmopolitan                                          6.456436
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                      7.838366
# E09000032            Wandsworth           London Cosmopolitan                                          5.647872
# E09000033            Westminster          NaN                                                          5.349826
#
#                                                                                      Fertility rates (age 20-24)  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                         66.5
# E06000002            Middlesbrough        Manufacturing Traits                                              68.4
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                         71.1
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                         63.2
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                         65.5
# ...                                                                                                          ...
# E09000029            Sutton               Suburban Traits                                                   42.3
# E09000030            Tower Hamlets        London Cosmopolitan                                               23.3
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                           41.5
# E09000032            Wandsworth           London Cosmopolitan                                               13.5
# E09000033            Westminster          NaN                                                               10.4
#
#                                                                                      Fertility rates (age < 20)  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                        19.2
# E06000002            Middlesbrough        Manufacturing Traits                                             19.3
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                        20.9
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                        14.9
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                        17.3
# ...                                                                                                         ...
# E09000029            Sutton               Suburban Traits                                                   6.0
# E09000030            Tower Hamlets        London Cosmopolitan                                               3.2
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                           6.6
# E09000032            Wandsworth           London Cosmopolitan                                               3.9
# E09000033            Westminster          NaN                                                               1.7
#
#                                                                                      IMD Health  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy       0.869
# E06000002            Middlesbrough        Manufacturing Traits                            1.194
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy       0.790
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy       0.684
# E06000005            Darlington           Services, Manufacturing and Mining Legacy       0.532
# ...                                                                                         ...
# E09000029            Sutton               Suburban Traits                                -0.570
# E09000030            Tower Hamlets        London Cosmopolitan                             0.195
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living        -0.161
# E09000032            Wandsworth           London Cosmopolitan                            -0.388
# E09000033            Westminster          NaN                                            -0.855
#
#                                                                                      IMD Crime  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy      0.566
# E06000002            Middlesbrough        Manufacturing Traits                           0.701
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy      0.138
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy     -0.111
# E06000005            Darlington           Services, Manufacturing and Mining Legacy      0.558
# ...                                                                                        ...
# E09000029            Sutton               Suburban Traits                               -0.174
# E09000030            Tower Hamlets        London Cosmopolitan                            0.509
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living        0.406
# E09000032            Wandsworth           London Cosmopolitan                            0.118
# E09000033            Westminster          NaN                                            0.105
#
#                                                                                      Lone parent households  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy               11.085973
# E06000002            Middlesbrough        Manufacturing Traits                                    15.806988
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                9.841270
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy               10.440835
# E06000005            Darlington           Services, Manufacturing and Mining Legacy               11.205074
# ...                                                                                                     ...
# E09000029            Sutton               Suburban Traits                                         16.919192
# E09000030            Tower Hamlets        London Cosmopolitan                                      7.588933
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                 14.522059
# E09000032            Wandsworth           London Cosmopolitan                                      5.667412
# E09000033            Westminster          NaN                                                     11.604096
#
#                                                                                      Pupils with SEN support  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                15.281077
# E06000002            Middlesbrough        Manufacturing Traits                                     14.169557
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                14.431018
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                12.675524
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                13.776228
# ...                                                                                                      ...
# E09000029            Sutton               Suburban Traits                                           9.569244
# E09000030            Tower Hamlets        London Cosmopolitan                                      12.400140
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                  11.529270
# E09000032            Wandsworth           London Cosmopolitan                                      13.868613
# E09000033            Westminster          NaN                                                      13.564739
#
#                                                                                      Qualification below level 2 (age 16-24)  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                                24.069780
# E06000002            Middlesbrough        Manufacturing Traits                                                     23.646299
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                                25.320197
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                                23.853056
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                                24.413571
# ...                                                                                                                      ...
# E09000029            Sutton               Suburban Traits                                                          19.199102
# E09000030            Tower Hamlets        London Cosmopolitan                                                      13.133683
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                                  20.202765
# E09000032            Wandsworth           London Cosmopolitan                                                      11.902539
# E09000033            Westminster          NaN                                                                       9.945883
#
#                                                                                      Qualification below level 2 (all)  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                          33.359578
# E06000002            Middlesbrough        Manufacturing Traits                                               35.188001
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                          32.094161
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                          28.419422
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                          28.626379
# ...                                                                                                                ...
# E09000029            Sutton               Suburban Traits                                                    24.776830
# E09000030            Tower Hamlets        London Cosmopolitan                                                25.217391
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                            27.408201
# E09000032            Wandsworth           London Cosmopolitan                                                14.775547
# E09000033            Westminster          NaN                                                                19.227797
#
#                                                                                      School Absences  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy         7.947627
# E06000002            Middlesbrough        Manufacturing Traits                              8.776107
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy         7.883450
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy         7.732062
# E06000005            Darlington           Services, Manufacturing and Mining Legacy         7.674965
# ...                                                                                              ...
# E09000029            Sutton               Suburban Traits                                   6.916140
# E09000030            Tower Hamlets        London Cosmopolitan                               6.150389
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living           6.770535
# E09000032            Wandsworth           London Cosmopolitan                               6.493081
# E09000033            Westminster          NaN                                               7.345094
#
#                                                                                      School Exclusions  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy           0.104808
# E06000002            Middlesbrough        Manufacturing Traits                                0.177431
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy           0.306777
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy           0.118023
# E06000005            Darlington           Services, Manufacturing and Mining Legacy           0.187829
# ...                                                                                                ...
# E09000029            Sutton               Suburban Traits                                     0.110687
# E09000030            Tower Hamlets        London Cosmopolitan                                 0.019569
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living             0.059170
# E09000032            Wandsworth           London Cosmopolitan                                 0.029840
# E09000033            Westminster          NaN                                                 0.018272
#
#                                                                                      School Suspensions  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy           14.181842
# E06000002            Middlesbrough        Manufacturing Traits                                27.411087
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy           24.216789
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy           10.858154
# E06000005            Darlington           Services, Manufacturing and Mining Legacy           11.106937
# ...                                                                                                 ...
# E09000029            Sutton               Suburban Traits                                      4.860411
# E09000030            Tower Hamlets        London Cosmopolitan                                  2.800487
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living              4.371494
# E09000032            Wandsworth           London Cosmopolitan                                  3.327166
# E09000033            Westminster          NaN                                                  5.837749
#
#                                                                                      Socially renting households  \
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                    23.440592
# E06000002            Middlesbrough        Manufacturing Traits                                         23.240687
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                    18.899056
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                    16.324801
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                    16.213840
# ...                                                                                                          ...
# E09000029            Sutton               Suburban Traits                                              14.168094
# E09000030            Tower Hamlets        London Cosmopolitan                                          35.869719
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                      21.475982
# E09000032            Wandsworth           London Cosmopolitan                                          19.319902
# E09000033            Westminster          NaN                                                          28.275818
#
#                                                                                      Unpaid carer (age 16-24)
# Local Authority Code Local Authority Name Group
# E06000001            Hartlepool           Services, Manufacturing and Mining Legacy                  6.095155
# E06000002            Middlesbrough        Manufacturing Traits                                       5.045736
# E06000003            Redcar and Cleveland Services, Manufacturing and Mining Legacy                  5.750144
# E06000004            Stockton-on-Tees     Services, Manufacturing and Mining Legacy                  5.216711
# E06000005            Darlington           Services, Manufacturing and Mining Legacy                  5.257349
# ...                                                                                                       ...
# E09000029            Sutton               Suburban Traits                                            4.413100
# E09000030            Tower Hamlets        London Cosmopolitan                                        3.889538
# E09000031            Waltham Forest       Ethnically Diverse Metropolitan  Living                    4.554707
# E09000032            Wandsworth           London Cosmopolitan                                        3.157557
# E09000033            Westminster          NaN                                                        4.216120
#
# [309 rows x 18 columns]
